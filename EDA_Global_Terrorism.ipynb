# %% [markdown]
# # Author: Asif Saeed

# %% [markdown]
# ## Task#: 02 (Exploritry Data Analysis on global terrorism dataset)

# %% [markdown]
# ### Load Essential liberiries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
sns.set_theme()
# %matplotlib inline

# %%
data=pd.read_csv("Global_Terrorism_Dataset.csv", encoding=("ISO-8859-1"), low_memory=False)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### checking null values or insufficient data colomuns

# %%
data.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ### unhidden the null values beacuse it's to more

# %%
NAN_columns = data.isna().any()

# %%
columns_have_nan = data.columns[NAN_columns].tolist()

# %%
print(columns_have_nan)
# Out:
# ['approxdate', 'resolution', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'location', 'summary', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weapsubtype1', 'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4'
# ...

# %% [markdown]
# ### change the columns name for ease to understanding

# %%
data=data.rename(columns = {"iyear":"Year", "imonth":"Month", "iday":"Day","region_txt":"region_name","country_txt":"country_name",
                      "nwound":"wound", "targtype1_txt":"target_type","targtype1":"no_of_target_type","nkill":"kill"}, inplace = False)

# %%
pd.set_option("display.max_columns", None)
print(data.dtypes)
# Out:
# eventid        int64
# Year           int64
# Month          int64
# Day            int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# ### Extracting desire columns from dataset

# %%
data=data[["Year", "Month", "Day", "country_name","region_name","country","city","wound", "gname", "kill",
           "target_type","no_of_target_type","weaptype1_txt","weaptype1","summary"]]
data.head()
# Out:
#    Year  Month  Day        country_name                  region_name  country  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean       58
# 1  1970      0    0              Mexico                North America      130
# 2  1970      1    0         Philippines               Southeast Asia      160
# 3  1970      1    0              Greece               Western Europe       78
# 4  1970      1    0               Japan                    East Asia      101
#
#             city  wound                               gname  kill  \
# 0  Santo Domingo    0.0                              MANO-D   1.0
# 1    Mexico city    0.0  23rd of September Communist League   0.0
# 2        Unknown    0.0                             Unknown   1.0
# 3         Athens    NaN                             Unknown   NaN
# 4        Fukouka    NaN                             Unknown   NaN
#
#                    target_type  no_of_target_type weaptype1_txt  weaptype1  \
# ...

# %% [markdown]
# ### counting the value of each column

# %%
data.count()
# Out:
# Year                 181691
# Month                181691
# Day                  181691
# country_name         181691
# region_name          181691
# country              181691
# city                 181257
# wound                165380
# gname                181691
# kill                 171378
# target_type          181691
# no_of_target_type    181691
# weaptype1_txt        181691
# weaptype1            181691
# summary              115562
# dtype: int64

# %%
len(data)
# Out:
# 181691

# %%
data.isnull().sum()
# Out:
# Year                     0
# Month                    0
# Day                      0
# country_name             0
# region_name              0
# country                  0
# city                   434
# wound                16311
# gname                    0
# kill                 10313
# target_type              0
# no_of_target_type        0
# weaptype1_txt            0
# weaptype1                0
# summary              66129
# dtype: int64

# %%
m_percentage = data.isnull().sum()*100/len(data)
print(m_percentage)
# Out:
# Year                  0.000000
# Month                 0.000000
# Day                   0.000000
# country_name          0.000000
# region_name           0.000000
# country               0.000000
# city                  0.238867
# wound                 8.977330
# gname                 0.000000
# kill                  5.676120
# target_type           0.000000
# no_of_target_type     0.000000
# weaptype1_txt         0.000000
# weaptype1             0.000000
# summary              36.396409
# dtype: float64

# %% [markdown]
# ### using heatmap to identify the missing columns value

# %%
plt.figure(figsize=(7,6))
percent = sns.heatmap(data.isnull())
print(percent)
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# # missing of values in columns:
# --> city
# --> kill
# --> wound
# --> summary

# %% [markdown]
# ### filling zero where null values in column

# %%
data["kill"] = data["kill"].fillna(0)
data["wound"] = data["wound"].fillna(0)
data["summary"] = data["summary"].fillna(0)

# %% [markdown]
# ### filling 'unknown' where columns have null values

# %%
data["city"].fillna("Unknown", inplace = True)

# %%
data.head(10)
# Out:
#    Year  Month  Day        country_name                  region_name  country  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean       58
# 1  1970      0    0              Mexico                North America      130
# 2  1970      1    0         Philippines               Southeast Asia      160
# 3  1970      1    0              Greece               Western Europe       78
# 4  1970      1    0               Japan                    East Asia      101
# 5  1970      1    1       United States                North America      217
# 6  1970      1    2             Uruguay                South America      218
# 7  1970      1    2       United States                North America      217
# 8  1970      1    2       United States                North America      217
# 9  1970      1    3       United States                North America      217
#
#             city  wound                               gname  kill  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               181691 non-null  int64
#  1   Month              181691 non-null  int64
#  2   Day                181691 non-null  int64
#  3   country_name       181691 non-null  object
#  4   region_name        181691 non-null  object
#  5   country            181691 non-null  int64
#  6   city               181691 non-null  object
#  7   wound              181691 non-null  float64
#  8   gname              181691 non-null  object
#  9   kill               181691 non-null  float64
#  10  target_type        181691 non-null  object
#  11  no_of_target_type  181691 non-null  int64
#  12  weaptype1_txt      181691 non-null  object
#  13  weaptype1          181691 non-null  int64
#  14  summary            181691 non-null  object
# ...

# %% [markdown]
# ### droping those columns whose have null values

# %%
data.dropna(axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Year  Month  Day        country_name                  region_name  country  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean       58
# 1  1970      0    0              Mexico                North America      130
# 2  1970      1    0         Philippines               Southeast Asia      160
# 3  1970      1    0              Greece               Western Europe       78
# 4  1970      1    0               Japan                    East Asia      101
#
#             city  wound                               gname  kill  \
# 0  Santo Domingo    0.0                              MANO-D   1.0
# 1    Mexico city    0.0  23rd of September Communist League   0.0
# 2        Unknown    0.0                             Unknown   1.0
# 3         Athens    0.0                             Unknown   0.0
# 4        Fukouka    0.0                             Unknown   0.0
#
#                    target_type  no_of_target_type weaptype1_txt  weaptype1  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               181691 non-null  int64
#  1   Month              181691 non-null  int64
#  2   Day                181691 non-null  int64
#  3   country_name       181691 non-null  object
#  4   region_name        181691 non-null  object
#  5   country            181691 non-null  int64
#  6   city               181691 non-null  object
#  7   wound              181691 non-null  float64
#  8   gname              181691 non-null  object
#  9   kill               181691 non-null  float64
#  10  target_type        181691 non-null  object
#  11  no_of_target_type  181691 non-null  int64
#  12  weaptype1_txt      181691 non-null  object
#  13  weaptype1          181691 non-null  int64
#  14  summary            181691 non-null  object
# ...

# %% [markdown]
# ### Here are the 10 countries with the highest number of loses

# %%
plt.figure(figsize=(15,6))
plt.bar(list(data["country_name"].value_counts()[0:10].keys()), list(data["kill"].value_counts()[0:10]), color = "r")
plt.ylabel("No. Of Kills", fontsize = 18)
plt.xticks(rotation = 90)
plt.xlabel("Attacks on Country",fontsize = 18)
plt.title("Most kills Vs Country")
plt.show()

# %%
kills_most = data[data["kill"] >= 1000]

# %%
kills_most.head()
# Out:
#         Year  Month  Day   country_name                 region_name  country  \
# 55934   1994      4   13         Rwanda          Sub-Saharan Africa      168
# 73126   2001      9   11  United States               North America      217
# 73127   2001      9   11  United States               North America      217
# 133518  2014      6   12           Iraq  Middle East & North Africa       95
#
#                  city   wound                                        gname  \
# 55934          Gikoro     0.0                              Hutu extremists
# 73126   New York City  8190.0                                     Al-Qaida
# 73127   New York City  8191.0                                     Al-Qaida
# 133518         Tikrit     0.0  Islamic State of Iraq and the Levant (ISIL)
#
#           kill                  target_type  no_of_target_type  \
# 55934   1180.0  Private Citizens & Property                 14
# 73126   1384.0  Private Citizens & Property                 14
# ...

# %% [markdown]
# ### Here are the 10 countries with the highest number of wounds

# %%
plt.figure(figsize=(15,6))
plt.bar(list(data["country_name"].value_counts()[0:10].keys()), list(data["wound"].value_counts()[0:10]), color = "y")
plt.ylabel("No. of Wounds", fontsize = 18)
plt.xticks(rotation = 90)
plt.xlabel("Attacks on Country",fontsize = 18)
plt.title("Most Wounds Vs Country")
plt.show()

# %%
plt.rcParams["figure.figsize"] = 15,11
sns.barplot(x = data["country_name"].value_counts()[:10].index, y = data["country"].value_counts()[:10].values)
plt.ylabel("No. Of Attacks", fontsize = 18)
plt.xticks(rotation = 90)
plt.xlabel("Attacks on Country",fontsize = 18)
plt.title("NUmbers of Attacks On Country")
# Out:
# Text(0.5, 1.0, 'NUmbers of Attacks On Country')

# %%
plt.rcParams["figure.figsize"] = 15,11
sns.barplot(x = data["Year"].value_counts()[:10].index, y = data["country"].value_counts()[:10].values)
plt.ylabel("No. Of Attacks", fontsize = 18)
plt.xticks(rotation = 90)
plt.xlabel("Years",fontsize = 18)
# Out:
# Text(0.5, 0, 'Years')

# %%
pd.crosstab(data.Year, data.region_name).plot(kind = "area", stacked = False, figsize = (20,10))
plt.title("Attacks on each year by region")
plt.ylabel("No. Of Attacks", fontsize = 18)
plt.xlabel("Year",fontsize = 18)
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.rcParams["figure.figsize"] = 15,11
sns.barplot(x = data["target_type"].value_counts()[:10].index, y = data["country"].value_counts()[:10].values)
plt.ylabel("No. Of Targets", fontsize = 18)
plt.xticks(rotation = 90)
plt.xlabel("Target By",fontsize = 18)
plt.title("Numbers of Attacks by Forces")
# Out:
# Text(0.5, 1.0, 'Numbers of Attacks by Forces')

# %%
plt.rcParams["figure.figsize"] = 15,11
sns.barplot(x = data["gname"].value_counts()[:10].index, y = data["gname"].value_counts()[:10].values)
plt.ylabel("No of Attacks", fontsize = 18)
plt.xticks(rotation = 90)
plt.xlabel("",fontsize = 18)
plt.title("Number Attaks by Terrorist Group")
# Out:
# Text(0.5, 1.0, 'Number Attaks by Terrorist Group')

# %%
most_country_kills = data.pivot_table(columns = "country_name", values = "kill", aggfunc = "sum")

# %%
most_country_kills
# Out:
# country_name  Afghanistan  Albania  Algeria  Andorra  Angola  \
# kill              39384.0     42.0  11066.0      0.0  3043.0
#
# country_name  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# kill                          0.0      490.0     37.0       23.0     30.0
#
# country_name  Azerbaijan  Bahamas  Bahrain  Bangladesh  Barbados  Belarus  \
# kill               258.0      1.0     44.0      1244.0      76.0     14.0
#
# country_name  Belgium  Belize  Benin  Bhutan  Bolivia  Bosnia-Herzegovina  \
# kill             79.0     3.0    0.0     9.0     42.0                79.0
#
# country_name  Botswana  Brazil  Brunei  Bulgaria  Burkina Faso  Burundi  \
# kill              11.0   203.0     0.0      28.0         134.0   4205.0
#
# country_name  Cambodia  Cameroon  Canada  Central African Republic    Chad  \
# kill             543.0    2347.0   365.0                    1990.0  1119.0
#
# country_name  Chile   China  Colombia  Comoros  Costa Rica  Croatia  Cuba  \
# ...

# %% [markdown]
# # Thank You! Letsgrowmore
